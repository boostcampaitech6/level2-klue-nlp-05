# %% [markdown]
# train dataset에서 tokenizing을 수행했을 때, 최대 길이를 알아보고자 한다.

# %%
from transformers import AutoTokenizer, AutoConfig, AutoModelForSequenceClassification, Trainer, TrainingArguments
from omegaconf import OmegaConf
from dataset_utils import load_data, label_to_num, tokenized_dataset
from datasets import RE_Dataset
from metrics import compute_metrics

import numpy as np
import pandas as pd
import argparse
import random
import torch
import wandb
import os

# %%
tokenizer = AutoTokenizer.from_pretrained("klue/bert-base")
train_dataset = load_data("../dataset/train/train.csv")
test_dataset = load_data("../dataset/test/test_data.csv")
# tokenized_train = tokenized_dataset(train_dataset, tokenizer)

# %% [markdown]
# Autotokenizer의 tokenizer 매개 변수 중 padding되는 기준과 과정에 대해 알아봐야 할 것 같다.

# %% [markdown]
# train data의 EDA

# %%
pd.set_option('display.max_rows', None)

# %%
test_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7765 entries, 0 to 7764
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              7765 non-null   int64
#  1   sentence        7765 non-null   object
#  2   subject_entity  7765 non-null   object
#  3   object_entity   7765 non-null   object
#  4   label           7765 non-null   int64
#  5   source          7765 non-null   object
# dtypes: int64(2), object(4)
# memory usage: 364.1+ KB

# %%
train_dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32470 entries, 0 to 32469
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              32470 non-null  int64
#  1   sentence        32470 non-null  object
#  2   subject_entity  32470 non-null  object
#  3   object_entity   32470 non-null  object
#  4   label           32470 non-null  object
#  5   source          32470 non-null  object
# dtypes: int64(1), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# 중복 데이터 확인

# %%
df = load_data("../dataset/train/train.csv")

# %%
df.head()
# Out:
#    id                                           sentence  \
# 0   0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1   1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2   2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3   3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4   4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
#
#                                       subject_entity  \
# 0  {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 1  {'word': '민주평화당', 'start_idx': 19, 'end_idx': ...
# 2  {'word': '광주FC', 'start_idx': 21, 'end_idx': 2...
# 3  {'word': '아성다이소', 'start_idx': 13, 'end_idx': ...
# 4  {'word': '요미우리 자이언츠', 'start_idx': 22, 'end_id...
#
#                                        object_entity  \
# 0  {'word': '조지 해리슨', 'start_idx': 13, 'end_idx':...
# 1  {'word': '대안신당', 'start_idx': 14, 'end_idx': 1...
# 2  {'word': '한국프로축구연맹', 'start_idx': 34, 'end_idx...
# 3  {'word': '박정부', 'start_idx': 22, 'end_idx': 24...
# ...

# %%
# sentence, subj_entity, obj_entity, label이 중복되는 data를 찾기
duplicated_df=df[df.duplicated(['sentence', 'subject_entity','object_entity','label'], keep=False)]

# %%
duplicated_df.sort_values(by=['sentence'])
# Out:
#           id                                           sentence  \
# 22090  22090  1959-60 시즌 이후의 알파 에트니키 / 수페르리가 엘라다, 그리스 컵, 그리고...
# 9618    9618  1959-60 시즌 이후의 알파 에트니키 / 수페르리가 엘라다, 그리스 컵, 그리고...
# 25368  25368  2001년 4월 민주국민당 김윤환 의원과 민주당 의원 사이의 정책 연합과 관련한 통...
# 2500    2500  2001년 4월 민주국민당 김윤환 의원과 민주당 의원 사이의 정책 연합과 관련한 통...
# 3547    3547  2010년 10월 15일 전라북도청을 방문한 맹형규 행정안전부 장관은 도내 지자체간...
# 255      255  2010년 10월 15일 전라북도청을 방문한 맹형규 행정안전부 장관은 도내 지자체간...
# 13993  13993  4.15 총선 후보로 공천됐다가 최소된 미래통합당 김원성 최고위원이 유서를 남기고 ...
# 31510  31510  4.15 총선 후보로 공천됐다가 최소된 미래통합당 김원성 최고위원이 유서를 남기고 ...
# 16145  16145  ‘문재인 영입 인사’로 발탁돼 제20대 총선에 광주 서구을에 출마했고, 더불어민주당...
# 27116  27116  ‘문재인 영입 인사’로 발탁돼 제20대 총선에 광주 서구을에 출마했고, 더불어민주당...
# 28010  28010  가평군은 잣나무 면적이 약 20,000ha정도로서 전국적으로 가장 많은 잣을 생산할...
# 27793  27793  가평군은 잣나무 면적이 약 20,000ha정도로서 전국적으로 가장 많은 잣을 생산할...
# 30820  30820         결국 2018년 초에 국민의당은 바른미래당과 민주평화당으로 갈라지고 말았다.
# 32274  32274         결국 2018년 초에 국민의당은 바른미래당과 민주평화당으로 갈라지고 말았다.
# ...

# %%
# sentence, sub_entity, obj_entity가 중복되는 data 제거하기
new_df = df.drop_duplicates(['sentence', 'subject_entity','object_entity','label'])
len(new_df) # 32470 -> 32428
# Out:
# 32428

# %%
# sentence, sub_entity, obj_entity가 중복되는 data 찾기
duplicated_df=new_df[new_df.duplicated(['sentence', 'subject_entity','object_entity'], keep=False)]

# %%
duplicated_df.sort_values(by=['sentence', 'label'])
# Out:
#           id                                           sentence  \
# 6749    6749  대한항공은 5일 조양호 회장의 3자녀가 보유한 싸이버스카이 주식 9만9900주 전량...
# 12829  12829  대한항공은 5일 조양호 회장의 3자녀가 보유한 싸이버스카이 주식 9만9900주 전량...
# 8364    8364  배우 김병철 씨가 연기하는 정복동은 천리마마트를 망하게 하기 위해 여러 계획을 세우...
# 32299  32299  배우 김병철 씨가 연기하는 정복동은 천리마마트를 망하게 하기 위해 여러 계획을 세우...
# 22258  22258  영화 '버즈 오브 프레이'는 배트맨이 없는 고담시에서 할리퀸, 헌트리스, 블랙 카나...
# 11511  11511  영화 '버즈 오브 프레이'는 배트맨이 없는 고담시에서 할리퀸, 헌트리스, 블랙 카나...
# 277      277  이날 프로그램 공개에서는 전북영산작법보존회와 김명신‧정상희의 사제동행 판소리, 관악...
# 3296    3296  이날 프로그램 공개에서는 전북영산작법보존회와 김명신‧정상희의 사제동행 판소리, 관악...
# 4212    4212  한편 전라남도는 최근 확진자가 발생한 순천시와 여수시에 마스크를 각각 2만장씩 총 ...
# 25094  25094  한편 전라남도는 최근 확진자가 발생한 순천시와 여수시에 마스크를 각각 2만장씩 총 ...
#
#                                           subject_entity  \
# 6749   {'word': '대한항공', 'start_idx': 0, 'end_idx': 3,...
# 12829  {'word': '대한항공', 'start_idx': 0, 'end_idx': 3,...
# 8364   {'word': '정복동', 'start_idx': 15, 'end_idx': 17...
# ...

# %%
# sentence, sub_entity, obj_entity가 중복되는 data에 대해 no_relation인 data들을 삭제
# id가 4212와 25094인 데이터에서 25094가 옳다고 생각
# 10661, 13311, 15845
idx_list = [12829, 32299, 11511, 3296, 25094]

for i in range(len(idx_list)):
    idx = new_df[new_df["id"] == idx_list[i]].index
    new_df.drop(idx, inplace=True)

len(new_df) # 32428 -> 32423
# Out:
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py:4167: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
# ...
